# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import gzip

import nltk
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize, sent_tokenize 
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
import string

import dask.dataframe as dd
from dask.multiprocessing import get

import swifter

# %%
meta_data = pd.read_csv('meta_new.csv')

# %%
meta_data.drop('Unnamed: 0', axis=1, inplace=True)

# %%
meta_data.head()
# Out:
#          asin                                              imUrl  \
# 0  0528881469  http://ecx.images-amazon.com/images/I/51FnRkJq...
# 1  0972683275  http://ecx.images-amazon.com/images/I/41hYJ9Mw...
# 2  1400532620  http://ecx.images-amazon.com/images/I/519ca3cu...
# 3  140053271X  http://ecx.images-amazon.com/images/I/51jat7CV...
# 4  1400532736  http://ecx.images-amazon.com/images/I/413fSdlM...
#
#                                          description  \
# 0  Like its award-winning predecessor, the Intell...
# 1  The VideoSecu TV mount is a mounting solution ...
# 2  Barnes & Noble Nook eReader - no 3GMeet nook. ...
# 3  Barnes & Noble Nook Simple Touch Wi-Fi ReaderI...
# 4  The NOOK Simple Touch eReader allows you to re...
#
#                                           categories  \
# 0  [['Electronics', 'GPS & Navigation', 'Vehicle ...
# 1  [['Electronics', 'Accessories & Supplies', 'Au...
# 2   [['Electronics', 'eBook Readers & Accessories']]
# 3  [['Electronics', 'eBook Readers & Accessories'...
# 4  [['Electronics', 'eBook Readers & Accessories'...
#
#                                                title   price  \
# 0  Rand McNally 528881469 7-inch Intelliroute TND...  299.99
# 1  VideoSecu 24&quot; Long Arm TV Wall Mount Low ...   29.99
# 2            Barnes &amp; Noble Nook eReader - no 3G   74.95
# 3  Barnes &amp; Noble Nook Simple Touch eBook Rea...   79.49
# 4                          Nook Simple Touch eReader   62.99
#
#                 salesRank                                            related  \
# 0                     NaN  {'also_viewed': ['B006ZOI9OY', 'B00C7FKT2A', '...
# 1                      {}  {'also_bought': ['B000X3KOD2', 'B0074FGR74', '...
# 2  {'Electronics': 23071}  {'also_bought': ['B0035CLBT4', 'B004X18N24', '...
# 3                     NaN  {'also_bought': ['B007UXNHNM', 'B007UXNHGY', '...
# 4   {'Electronics': 4945}  {'also_bought': ['B0055ZDRI2', 'B007UXNHGY', '...
#
#                 brand                                         stem_words
# 0                 NaN  ['predecessor', 'intellirout', 'devic', 'navig...
# 1           VideoSecu  ['tv', 'mount', 'solut', 'lcd', 'tv', 'mount',...
# 2  Barnes &amp; Noble  ['eread', 'nook', 'access', 'wifi', 'brows', '...
# 3  Barnes &amp; Noble  ['wifi', 'touch', 'batteri', 'life', 'ink', 'd...
# 4  Barnes &amp; Noble  ['eread', 'display', 'devic', 'conveni', 'read...

# %%
len(meta_data)
# Out:
# 26762

# %%
# get the stemmed or lemmatized words of product description 
#for word_type: use 'stem' for stemming and 'lemmatize' for lemmatization
def get_desc_words(text):
    word_type='lemmatize'
    nopunc= [char for char in text if char not in string.punctuation]
    nopunc = ''.join(nopunc)

    words = [word.lower() for word in nopunc.split() if word.lower() not in stopwords.words('english')]
    
    
    tagged = nltk.pos_tag(words) 
    
    nouns = []
    for word in tagged:
        if word[1]=='NN':
            nouns.append(word[0])

    if word_type=='stem' :
        ps = PorterStemmer()
        stemmed_words = []
        for w in nouns:
            stemmed_words.append(ps.stem(w))
        
        return stemmed_words
    
    if word_type=='lemmatize':
        lem = WordNetLemmatizer()
        lem_words = []
        for w in nouns:
            lem_words.append(lem.lemmatize(w))
        
        return lem_words

# %%
ddata = dd.from_pandas(meta_data, npartitions=5)

# %%
ddata.head()
# Out:
#          asin                                              imUrl  \
# 0  0528881469  http://ecx.images-amazon.com/images/I/51FnRkJq...
# 1  0972683275  http://ecx.images-amazon.com/images/I/41hYJ9Mw...
# 2  1400532620  http://ecx.images-amazon.com/images/I/519ca3cu...
# 3  140053271X  http://ecx.images-amazon.com/images/I/51jat7CV...
# 4  1400532736  http://ecx.images-amazon.com/images/I/413fSdlM...
#
#                                          description  \
# 0  Like its award-winning predecessor, the Intell...
# 1  The VideoSecu TV mount is a mounting solution ...
# 2  Barnes & Noble Nook eReader - no 3GMeet nook. ...
# 3  Barnes & Noble Nook Simple Touch Wi-Fi ReaderI...
# 4  The NOOK Simple Touch eReader allows you to re...
#
#                                           categories  \
# 0  [['Electronics', 'GPS & Navigation', 'Vehicle ...
# 1  [['Electronics', 'Accessories & Supplies', 'Au...
# 2   [['Electronics', 'eBook Readers & Accessories']]
# 3  [['Electronics', 'eBook Readers & Accessories'...
# 4  [['Electronics', 'eBook Readers & Accessories'...
#
#                                                title   price  \
# 0  Rand McNally 528881469 7-inch Intelliroute TND...  299.99
# 1  VideoSecu 24&quot; Long Arm TV Wall Mount Low ...   29.99
# 2            Barnes &amp; Noble Nook eReader - no 3G   74.95
# 3  Barnes &amp; Noble Nook Simple Touch eBook Rea...   79.49
# 4                          Nook Simple Touch eReader   62.99
#
#                 salesRank                                            related  \
# 0                     NaN  {'also_viewed': ['B006ZOI9OY', 'B00C7FKT2A', '...
# 1                      {}  {'also_bought': ['B000X3KOD2', 'B0074FGR74', '...
# 2  {'Electronics': 23071}  {'also_bought': ['B0035CLBT4', 'B004X18N24', '...
# 3                     NaN  {'also_bought': ['B007UXNHNM', 'B007UXNHGY', '...
# 4   {'Electronics': 4945}  {'also_bought': ['B0055ZDRI2', 'B007UXNHGY', '...
#
#                 brand                                         stem_words
# 0                 NaN  ['predecessor', 'intellirout', 'devic', 'navig...
# 1           VideoSecu  ['tv', 'mount', 'solut', 'lcd', 'tv', 'mount',...
# 2  Barnes &amp; Noble  ['eread', 'nook', 'access', 'wifi', 'brows', '...
# 3  Barnes &amp; Noble  ['wifi', 'touch', 'batteri', 'life', 'ink', 'd...
# 4  Barnes &amp; Noble  ['eread', 'display', 'devic', 'conveni', 'read...

# %%
#meta_data['lem_words'] = ddata.map_partitions(lambda df: df.apply(lambda row: get_desc_words(row['description']), axis=1)).compute(scheduler=get)

# %%
## Using Swifter for applying the function
meta_data['lem_words'] = meta_data['description'].swifter.apply(get_desc_words)
# Out:
# Pandas Apply: 100%|██████████████████████████████████████████████████████████████| 26762/26762 [37:09<00:00, 12.00it/s]

# %%
meta_data.head()
# Out:
#          asin                                              imUrl  \
# 0  0528881469  http://ecx.images-amazon.com/images/I/51FnRkJq...
# 1  0972683275  http://ecx.images-amazon.com/images/I/41hYJ9Mw...
# 2  1400532620  http://ecx.images-amazon.com/images/I/519ca3cu...
# 3  140053271X  http://ecx.images-amazon.com/images/I/51jat7CV...
# 4  1400532736  http://ecx.images-amazon.com/images/I/413fSdlM...
#
#                                          description  \
# 0  Like its award-winning predecessor, the Intell...
# 1  The VideoSecu TV mount is a mounting solution ...
# 2  Barnes & Noble Nook eReader - no 3GMeet nook. ...
# 3  Barnes & Noble Nook Simple Touch Wi-Fi ReaderI...
# 4  The NOOK Simple Touch eReader allows you to re...
#
#                                           categories  \
# 0  [['Electronics', 'GPS & Navigation', 'Vehicle ...
# 1  [['Electronics', 'Accessories & Supplies', 'Au...
# 2   [['Electronics', 'eBook Readers & Accessories']]
# 3  [['Electronics', 'eBook Readers & Accessories'...
# 4  [['Electronics', 'eBook Readers & Accessories'...
#
#                                                title   price  \
# 0  Rand McNally 528881469 7-inch Intelliroute TND...  299.99
# 1  VideoSecu 24&quot; Long Arm TV Wall Mount Low ...   29.99
# 2            Barnes &amp; Noble Nook eReader - no 3G   74.95
# 3  Barnes &amp; Noble Nook Simple Touch eBook Rea...   79.49
# 4                          Nook Simple Touch eReader   62.99
#
#                 salesRank                                            related  \
# 0                     NaN  {'also_viewed': ['B006ZOI9OY', 'B00C7FKT2A', '...
# 1                      {}  {'also_bought': ['B000X3KOD2', 'B0074FGR74', '...
# 2  {'Electronics': 23071}  {'also_bought': ['B0035CLBT4', 'B004X18N24', '...
# 3                     NaN  {'also_bought': ['B007UXNHNM', 'B007UXNHGY', '...
# 4   {'Electronics': 4945}  {'also_bought': ['B0055ZDRI2', 'B007UXNHGY', '...
#
#                 brand                                         stem_words  \
# 0                 NaN  ['predecessor', 'intellirout', 'devic', 'navig...
# 1           VideoSecu  ['tv', 'mount', 'solut', 'lcd', 'tv', 'mount',...
# 2  Barnes &amp; Noble  ['eread', 'nook', 'access', 'wifi', 'brows', '...
# 3  Barnes &amp; Noble  ['wifi', 'touch', 'batteri', 'life', 'ink', 'd...
# 4  Barnes &amp; Noble  ['eread', 'display', 'devic', 'conveni', 'read...
#
#                                            lem_words
# 0  [predecessor, intelliroute, device, navigation...
# 1  [tv, mount, solution, lcd, tv, mounting, hole,...
# 2  [ereader, nook, access, wifi, browse, ebook, c...
# 3  [wifi, touch, battery, life, ink, display, w, ...
# 4  [ereader, display, device, convenience, readin...

# %%
meta_data.to_csv('meta_data_latest.csv',index=False)

# %%
#meta_data['lem_words'] = meta_data['description'].apply(get_desc_words)

# %%
4:15

# %%
df = pd.read_csv('Amazon_Gt_10')

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df.head()
# Out:
#        reviewerID        asin                     reviewerName   helpful  \
# 0   AMO214LNFCEI4  0528881469                  Amazon Customer  [12, 15]
# 1  A3N7T0DY83Y4IG  0528881469                    C. A. Freeman  [43, 45]
# 2  A1H8PY3QHMQQA0  0528881469         Dave M. Shaw "mack dave"   [9, 10]
# 3  A3QH8VQDE7HZCR  0972683275                   costaricachris  [15, 19]
# 4  A38FGQVJM18OWV  0972683275  George S. Mitchell "gsmitchell"   [8, 18]
#
#                                           reviewText  overall  \
# 0  I'm a professional OTR truck driver, and I bou...      1.0
# 1  Well, what can I say.  I've had this unit in m...      3.0
# 2  Not going to write a long review, even thought...      2.0
# 3  Quality was excellent. Instructions were clear...      5.0
# 4  I checked around Amazon as well as some other ...      1.0
#
#                     summary  unixReviewTime   reviewTime  helpfulness_score  \
# 0         Very Disappointed      1290643200  11 25, 2010           0.800000
# 1            1st impression      1283990400   09 9, 2010           0.955556
# 2   Great grafics, POOR GPS      1290556800  11 24, 2010           0.900000
# 3  Real value for the money      1286236800   10 5, 2010           0.789474
# 4     What a piece of junk!      1291161600   12 1, 2010           0.444444
#
#    user_deviation  review_delay
# 0        1.399189       6652800
# 1        0.624437             0
# 2        0.510375       6566400
# 3        0.442171       2678400
# 4        1.616074       7603200

# %%
len(df)
# Out:
# 107502

# %%
#get the list of pids
pids = list(meta_data['asin'])
#make function

def review_in_products(pid):
    return pid in pids

# %%
# Some products with Null Description values have been removed .
# Reviews corresponding to those product are removed here

df_new = df[df['asin'].apply(review_in_products) == True]

# %%
len(df_new)
# Out:
# 81620

# %%
df_new.to_csv('Amazon_Latest_Data.csv',index=False)

# %%
# get the stemmed words of  review text 
def get_review_words_stem(text):
    nopunc= [char for char in text if char not in string.punctuation]
    nopunc = ''.join(nopunc)

    words = [word.lower() for word in nopunc.split() if word.lower() not in stopwords.words('english')]
    
    ps = PorterStemmer()
    stemmed_words = []
    for w in words:
        stemmed_words.append(ps.stem(w))

    return stemmed_words

# %%
# get the lemmatized words of  review text 
def get_review_words_lem(text):
   
    nopunc= [char for char in text if char not in string.punctuation]
    nopunc = ''.join(nopunc)

    words = [word.lower() for word in nopunc.split() if word.lower() not in stopwords.words('english')]

    lem = WordNetLemmatizer()
    lem_words = []
    for w in words:
        lem_words.append(lem.lemmatize(w))

    return lem_words

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\Trishul\Anaconda3\lib\site-packages\swifter\swifter.py in apply(self, func, convert_dtype, args, **kwds)
#      77             tmp_df = func(samp, *args, **kwds)
# ---> 78             assert tmp_df.shape == samp.apply(func, convert_dtype=convert_dtype, args=args, **kwds).shape
#      79             return func(self._obj, *args, **kwds)
#
# AttributeError: 'list' object has no attribute 'shape'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-32a82e547a58> in <module>()
# ----> 1 df_new['stem_words'] = df['reviewText'].swifter.apply(get_review_words_stem)
#
# C:\Users\Trishul\Anaconda3\lib\site-packages\swifter\swifter.py in apply(self, func, convert_dtype, args, **kwds)
#      81             wrapped = self._wrapped_apply(func, convert_dtype=convert_dtype, args=args, **kwds)
#      82             n_repeats = 3
# ---> 83             timed = timeit.timeit(wrapped, number=n_repeats)
#      84             samp_proc_est = timed / n_repeats
#      85             est_apply_duration = samp_proc_est / SAMP_SIZE * self._obj.shape[0]
#
# C:\Users\Trishul\Anaconda3\lib\timeit.py in timeit(stmt, setup, timer, number, globals)
#     231            number=default_number, globals=None):
#     232     """Convenience function to create Timer object and call timeit method."""
# --> 233     return Timer(stmt, setup, timer, globals).timeit(number)
#     234
#     235 def repeat(stmt="pass", setup="pass", timer=default_timer,
#
# C:\Users\Trishul\Anaconda3\lib\timeit.py in timeit(self, number)
#     176         gc.disable()
#     177         try:
# --> 178             timing = self.inner(it, self.timer)
#     179         finally:
#     180             if gcold:
#
# C:\Users\Trishul\Anaconda3\lib\timeit.py in inner(_it, _timer, _stmt)
#
# C:\Users\Trishul\Anaconda3\lib\site-packages\swifter\swifter.py in wrapped()
#      39     def _wrapped_apply(self, func, convert_dtype=True, args=(), **kwds):
#      40         def wrapped():
# ---> 41             self._obj.iloc[:SAMP_SIZE].apply(func, convert_dtype=convert_dtype, args=args, **kwds)
#      42
#      43         return wrapped
#
# C:\Users\Trishul\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3192             else:
#    3193                 values = self.astype(object).values
# -> 3194                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3195
#    3196         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src\inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-50-7d305ee4d496> in get_review_words_stem(text)
#       1 # get the stemmed words of  review text
#       2 def get_review_words_stem(text):
# ----> 3     nopunc= [char for char in text if char not in string.punctuation]
#       4     nopunc = ''.join(nopunc)
#       5
#
# TypeError: 'float' object is not iterable

# %%
df_new.dropna(subset=['reviewText'],inplace=True)
# Out:
# C:\Users\Trishul\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_new['reviewText'].isnull().values.ravel().sum()
# Out:
# 0

# %%
df_new['stem_words'] = df_new['reviewText'].swifter.apply(get_review_words_stem)
# Out:
# Pandas Apply: 100%|████████████████████████████████████████████████████████████| 81275/81275 [2:58:02<00:00,  5.67it/s]
# C:\Users\Trishul\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_new['stem_words'].head()[0]
# Out:
# ['im',
#  'profession',
#  'otr',
#  'truck',
#  'driver',
#  'bought',
#  'tnd',
#  '700',
#  'truck',
#  'stop',
#  'hope',
#  'make',
#  'life',
#  'easier',
#  'rand',
#  'mcnalli',
#  'listeningfirst',
#  'thing',
#  'charg',
#  'connect',
#  'laptop',
#  'instal',
#  'softwar',
#  'attempt',
#  'updat',
#  'softwar',
#  'detect',
#  'problem',
#  'updat',
#  'want',
#  'home',
#  'address',
#  'could',
#  'sent',
#  'patch',
#  'sd',
#  'card',
#  'hello',
#  'dont',
#  'think',
#  'im',
#  'unusu',
#  'home',
#  'address',
#  'po',
#  'box',
#  'friend',
#  'check',
#  'weekli',
#  'might',
#  'get',
#  'check',
#  'everi',
#  'six',
#  'month',
#  'live',
#  'truck',
#  'truck',
#  'stop',
#  'need',
#  'make',
#  'patch',
#  'avail',
#  'sd',
#  'card',
#  'send',
#  'sd',
#  'card',
#  'truck',
#  'stop',
#  'devic',
#  'sold',
#  'ran',
#  'updat',
#  'program',
#  'multipl',
#  'time',
#  'program',
#  'said',
#  'tnd',
#  '700',
#  'complet',
#  'updatedi',
#  'program',
#  'height',
#  '136',
#  'length',
#  '53',
#  'weight',
#  '80000',
#  'rig',
#  'told',
#  'prefer',
#  'highway',
#  'park',
#  'truck',
#  'stop',
#  'cincinnati',
#  'oh',
#  'area',
#  'next',
#  'pickup',
#  '15',
#  'mile',
#  'freeway',
#  'side',
#  'coupl',
#  'block',
#  'cell',
#  'phone',
#  'gp',
#  'sprint',
#  'said',
#  'get',
#  'freeway',
#  'get',
#  'pickup',
#  'tnd',
#  '700',
#  'rout',
#  'thru',
#  '23',
#  'mile',
#  'residenti',
#  'street',
#  'final',
#  'get',
#  'pickup',
#  'excit',
#  'especi',
#  'sinc',
#  'everi',
#  'time',
#  'refus',
#  'turn',
#  'street',
#  'post',
#  'truck',
#  'tnd',
#  '700',
#  'took',
#  'almost',
#  '5',
#  'minut',
#  'figur',
#  'rerout',
#  'happen',
#  'multipl',
#  'time',
#  'short',
#  'tripi',
#  'decid',
#  'give',
#  'anoth',
#  'chanc',
#  'pickup',
#  'north',
#  'side',
#  'cincinnati',
#  'i75',
#  'need',
#  'head',
#  'phoenix',
#  'az',
#  'via',
#  'i71',
#  'easi',
#  'rout',
#  'hop',
#  'i75',
#  'drive',
#  'west',
#  'south',
#  'intersect',
#  'i71',
#  'inde',
#  'cell',
#  'phone',
#  'advis',
#  'tnd',
#  '700',
#  'howev',
#  'want',
#  'rout',
#  'surfac',
#  'street',
#  'across',
#  'citi',
#  'pick',
#  'i75',
#  'side',
#  'citi',
#  'turn',
#  'next',
#  'time',
#  'pass',
#  'truck',
#  'stop',
#  'chain',
#  'purchas',
#  'return',
#  'got',
#  'money',
#  'backi',
#  'spent',
#  '30',
#  'cheap',
#  'printer',
#  'take',
#  'minut',
#  'set',
#  'rout',
#  'googl',
#  'print',
#  'hasnt',
#  'gotten',
#  'lost',
#  'yet',
#  'sever',
#  'cross',
#  'countri',
#  'trip']

# %%
df_new['lem_words']= df_new['reviewText'].swifter.apply(get_review_words_lem)
# Out:
# Pandas Apply: 100%|███████████████████████████████████████████████████████████| 81275/81275 [19:18:17<00:00,  4.03it/s]
# C:\Users\Trishul\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_new.head()
# Out:
#        reviewerID        asin                     reviewerName   helpful  \
# 0   AMO214LNFCEI4  0528881469                  Amazon Customer  [12, 15]
# 1  A3N7T0DY83Y4IG  0528881469                    C. A. Freeman  [43, 45]
# 2  A1H8PY3QHMQQA0  0528881469         Dave M. Shaw "mack dave"   [9, 10]
# 3  A3QH8VQDE7HZCR  0972683275                   costaricachris  [15, 19]
# 4  A38FGQVJM18OWV  0972683275  George S. Mitchell "gsmitchell"   [8, 18]
#
#                                           reviewText  overall  \
# 0  I'm a professional OTR truck driver, and I bou...      1.0
# 1  Well, what can I say.  I've had this unit in m...      3.0
# 2  Not going to write a long review, even thought...      2.0
# 3  Quality was excellent. Instructions were clear...      5.0
# 4  I checked around Amazon as well as some other ...      1.0
#
#                     summary  unixReviewTime   reviewTime  helpfulness_score  \
# 0         Very Disappointed      1290643200  11 25, 2010           0.800000
# 1            1st impression      1283990400   09 9, 2010           0.955556
# 2   Great grafics, POOR GPS      1290556800  11 24, 2010           0.900000
# 3  Real value for the money      1286236800   10 5, 2010           0.789474
# 4     What a piece of junk!      1291161600   12 1, 2010           0.444444
#
#    user_deviation  review_delay  \
# 0        1.399189       6652800
# 1        0.624437             0
# 2        0.510375       6566400
# 3        0.442171       2678400
# 4        1.616074       7603200
#
#                                           stem_words  \
# 0  [im, profession, otr, truck, driver, bought, t...
# 1  [well, say, ive, unit, truck, four, day, prior...
# 2  [go, write, long, review, even, thought, unit,...
# 3  [qualiti, excel, instruct, clear, clear, tilt,...
# 4  [check, around, amazon, well, site, decid, nee...
#
#                                            lem_words
# 0  [im, professional, otr, truck, driver, bought,...
# 1  [well, say, ive, unit, truck, four, day, prior...
# 2  [going, write, long, review, even, thought, un...
# 3  [quality, excellent, instruction, clear, clear...
# 4  [checked, around, amazon, well, site, decided,...

# %%
df_new.to_csv('Amazon_Latest.csv',index=False)

# %%
meta_data.head()
# Out:
#          asin                                              imUrl  \
# 0  0528881469  http://ecx.images-amazon.com/images/I/51FnRkJq...
# 1  0972683275  http://ecx.images-amazon.com/images/I/41hYJ9Mw...
# 2  1400532620  http://ecx.images-amazon.com/images/I/519ca3cu...
# 3  140053271X  http://ecx.images-amazon.com/images/I/51jat7CV...
# 4  1400532736  http://ecx.images-amazon.com/images/I/413fSdlM...
#
#                                          description  \
# 0  Like its award-winning predecessor, the Intell...
# 1  The VideoSecu TV mount is a mounting solution ...
# 2  Barnes & Noble Nook eReader - no 3GMeet nook. ...
# 3  Barnes & Noble Nook Simple Touch Wi-Fi ReaderI...
# 4  The NOOK Simple Touch eReader allows you to re...
#
#                                           categories  \
# 0  [['Electronics', 'GPS & Navigation', 'Vehicle ...
# 1  [['Electronics', 'Accessories & Supplies', 'Au...
# 2   [['Electronics', 'eBook Readers & Accessories']]
# 3  [['Electronics', 'eBook Readers & Accessories'...
# 4  [['Electronics', 'eBook Readers & Accessories'...
#
#                                                title   price  \
# 0  Rand McNally 528881469 7-inch Intelliroute TND...  299.99
# 1  VideoSecu 24&quot; Long Arm TV Wall Mount Low ...   29.99
# 2            Barnes &amp; Noble Nook eReader - no 3G   74.95
# 3  Barnes &amp; Noble Nook Simple Touch eBook Rea...   79.49
# 4                          Nook Simple Touch eReader   62.99
#
#                 salesRank                                            related  \
# 0                     NaN  {'also_viewed': ['B006ZOI9OY', 'B00C7FKT2A', '...
# 1                      {}  {'also_bought': ['B000X3KOD2', 'B0074FGR74', '...
# 2  {'Electronics': 23071}  {'also_bought': ['B0035CLBT4', 'B004X18N24', '...
# 3                     NaN  {'also_bought': ['B007UXNHNM', 'B007UXNHGY', '...
# 4   {'Electronics': 4945}  {'also_bought': ['B0055ZDRI2', 'B007UXNHGY', '...
#
#                 brand                                         stem_words  \
# 0                 NaN  ['predecessor', 'intellirout', 'devic', 'navig...
# 1           VideoSecu  ['tv', 'mount', 'solut', 'lcd', 'tv', 'mount',...
# 2  Barnes &amp; Noble  ['eread', 'nook', 'access', 'wifi', 'brows', '...
# 3  Barnes &amp; Noble  ['wifi', 'touch', 'batteri', 'life', 'ink', 'd...
# 4  Barnes &amp; Noble  ['eread', 'display', 'devic', 'conveni', 'read...
#
#                                            lem_words
# 0  [predecessor, intelliroute, device, navigation...
# 1  [tv, mount, solution, lcd, tv, mounting, hole,...
# 2  [ereader, nook, access, wifi, browse, ebook, c...
# 3  [wifi, touch, battery, life, ink, display, w, ...
# 4  [ereader, display, device, convenience, readin...

# %%
meta_data[meta_data['asin']=='0972683275']['stem_words'].iloc[0]
# Out:
# "['tv', 'mount', 'solut', 'lcd', 'tv', 'mount', 'hole', 'pattern', 'tv', 'gaug', 'steel', 'construct', 'safeti', 'display', 'twolink', 'arm', 'design', 'extens', 'angl', 'vesa', 'plate', 'instal', 'postinstal', 'level', 'adjust', 'tv', 'arm', 'cabl', 'manag', 'ring', 'system', 'design', 'cabl', 'hardwar', 'note', 'product']"

# %%
def get_stem_sim_words(pid, stem_words) :
    # Get the stem words of the product
    desc_stem=meta_data[meta_data['asin']==pid]['stem_words'].iloc[0]
    # Find the Intersection of words
    sim_words=list(set(desc_stem).intersection(stem_words))
    # return the words
    return sim_words

# %%
def get_lem_sim_words(pid, lem_words) :
    # Get the stem words of the product
    desc_lem=meta_data[meta_data['asin']==pid]['lem_words'].iloc[0]
    # Find the Intersection of words
    sim_words=list(set(desc_lem).intersection(lem_words))
    # return the words
    return sim_words

# %%
df_new['stem_sim_words'] = df_new.swifter.apply(lambda row: get_stem_sim_words(row['asin'],row['stem_words']), axis=1)
# Out:
# Pandas Apply: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████| 81275/81275 [04:18<00:00, 313.82it/s]
# C:\Users\Trishul\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_new['lem_sim_words'] = df_new.swifter.apply(lambda row: get_lem_sim_words(row['asin'],row['lem_words']), axis=1)
# Out:
# Pandas Apply: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████| 81275/81275 [04:05<00:00, 331.45it/s]
# C:\Users\Trishul\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_new.tail()
# Out:
#             reviewerID        asin                      reviewerName  \
# 107497   APRNS6DB68LLV  B00L26YDA4  Rob Slaven "slavenrm@gmail. com"
# 107498  A3A4ZAIBQWKOZS  B00L26YDA4                  Stephen M. Lerch
# 107499   A18R0PC372EGL  B00L3YHF6O                             Blues
# 107500  A3OOQH73VQ97VN  B00L3YHF6O                   Jem "Microsoft"
# 107501  A3A4ZAIBQWKOZS  B00L3YHF6O                  Stephen M. Lerch
#
#          helpful                                         reviewText  overall  \
# 107497   [5, 10]  As usual I received this item for free in exch...      5.0
# 107498  [10, 15]  Want to add wireless audio streaming to your h...      5.0
# 107499   [7, 11]  Wow...that's about all I have to say.  Having ...      5.0
# 107500   [5, 12]  Update 14 July 2014: they have a white paper a...      5.0
# 107501  [18, 23]  My short review:If you have the money to spend...      5.0
#
#                                                   summary  unixReviewTime  \
# 107497  Works brilliantly once you understand what it ...      1404172800
# 107498                                              Smart      1403827200
# 107499                     To use a technical term...Wow!      1404950400
# 107500                                 Purely Cons Review      1404777600
# 107501          Best sounding speaker at this price range      1404691200
#
#          reviewTime  helpfulness_score  user_deviation  review_delay  \
# 107497   07 1, 2014           0.500000        0.597583        432000
# 107498  06 27, 2014           0.666667        0.546834         86400
# 107499  07 10, 2014           0.636364        0.448464        259200
# 107500   07 8, 2014           0.416667        0.742179         86400
# 107501   07 7, 2014           0.782609        0.546834             0
#
#                                                stem_words  \
# 107497  [usual, receiv, item, free, exchang, review, a...
# 107498  [want, add, wireless, audio, stream, home, the...
# 107499  [wowthat, say, prior, experi, bt, speaker, rel...
# 107500  [updat, 14, juli, 2014, white, paper, creative...
# 107501  [short, reviewif, money, spend, speaker, dont,...
#
#                                                 lem_words stem_sim_words  \
# 107497  [usual, received, item, free, exchange, review...             []
# 107498  [want, add, wireless, audio, streaming, home, ...             []
# 107499  [wowthats, say, prior, experience, bt, speaker...             []
# 107500  [update, 14, july, 2014, white, paper, creativ...            [g]
# 107501  [short, reviewif, money, spend, speaker, dont,...         [n, w]
#
#                                             lem_sim_words
# 107497               [receiver, speaker, get, wifi, need]
# 107498  [receiver, music, connection, wifi, sabrent, s...
# 107499         [fidelity, pair, performance, sound, roar]
# 107500    [sbx, control, audio, pair, power, panel, roar]
# 107501  [control, audio, pc, connection, pair, line, p...

# %%
df_new.to_csv('Amazon_Latest_Data.csv',index=False)

# %%
def get_set_length(words) :
    set_length = len(set(words))
    if(set_length==0):
        return 1
    return set_length

# %%
get_set_length(['wow', 'wow', 'how'])
# Out:
# 2

# %%
df_new['lem_set_length'] = df_new['lem_words'].swifter.apply(get_set_length)
# Out:
# Pandas Apply: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████| 81275/81275 [00:00<00:00, 88447.20it/s]
# C:\Users\Trishul\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_new.head()
# Out:
#        reviewerID        asin                     reviewerName   helpful  \
# 0   AMO214LNFCEI4  0528881469                  Amazon Customer  [12, 15]
# 1  A3N7T0DY83Y4IG  0528881469                    C. A. Freeman  [43, 45]
# 2  A1H8PY3QHMQQA0  0528881469         Dave M. Shaw "mack dave"   [9, 10]
# 3  A3QH8VQDE7HZCR  0972683275                   costaricachris  [15, 19]
# 4  A38FGQVJM18OWV  0972683275  George S. Mitchell "gsmitchell"   [8, 18]
#
#                                           reviewText  overall  \
# 0  I'm a professional OTR truck driver, and I bou...      1.0
# 1  Well, what can I say.  I've had this unit in m...      3.0
# 2  Not going to write a long review, even thought...      2.0
# 3  Quality was excellent. Instructions were clear...      5.0
# 4  I checked around Amazon as well as some other ...      1.0
#
#                     summary  unixReviewTime   reviewTime  helpfulness_score  \
# 0         Very Disappointed      1290643200  11 25, 2010           0.800000
# 1            1st impression      1283990400   09 9, 2010           0.955556
# 2   Great grafics, POOR GPS      1290556800  11 24, 2010           0.900000
# 3  Real value for the money      1286236800   10 5, 2010           0.789474
# 4     What a piece of junk!      1291161600   12 1, 2010           0.444444
#
#    user_deviation  review_delay  \
# 0        1.399189       6652800
# 1        0.624437             0
# 2        0.510375       6566400
# 3        0.442171       2678400
# 4        1.616074       7603200
#
#                                           stem_words  \
# 0  [im, profession, otr, truck, driver, bought, t...
# 1  [well, say, ive, unit, truck, four, day, prior...
# 2  [go, write, long, review, even, thought, unit,...
# 3  [qualiti, excel, instruct, clear, clear, tilt,...
# 4  [check, around, amazon, well, site, decid, nee...
#
#                                            lem_words stem_sim_words  \
# 0  [im, professional, otr, truck, driver, bought,...            [5]
# 1  [well, say, ive, unit, truck, four, day, prior...             []
# 2  [going, write, long, review, even, thought, un...             []
# 3  [quality, excellent, instruction, clear, clear...             []
# 4  [checked, around, amazon, well, site, decided,...             []
#
#                                        lem_sim_words  lem_set_length  \
# 0  [rand, route, weight, take, time, length, gps,...             160
# 1  [dock, feature, car, determine, home, rand, pa...             241
# 2  [screen, road, rand, route, truck, feature, tr...             159
# 3                                  [level, hardware]              31
# 4                                        [tv, mount]              52
#
#    lem_sim_length    lem_sim
# 0              13  12.307692
# 1              23  10.478261
# 2              16   9.937500
# 3               2  15.500000
# 4               2  26.000000

# %%
df_new['lem_sim_length'] = df_new['lem_sim_words'].swifter.apply(len)
# Out:
# Pandas Apply: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████| 81275/81275 [00:00<00:00, 571985.73it/s]
# C:\Users\Trishul\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_lem_sim(lem_length,sim_length):
    return sim_length/lem_length

# %%
df_new['lem_sim'] = df_new.swifter.apply(lambda row: get_lem_sim(row['lem_set_length'],row['lem_sim_length']), axis=1)
# Out:
# C:\Users\Trishul\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_new.head()
# Out:
#        reviewerID        asin                     reviewerName   helpful  \
# 0   AMO214LNFCEI4  0528881469                  Amazon Customer  [12, 15]
# 1  A3N7T0DY83Y4IG  0528881469                    C. A. Freeman  [43, 45]
# 2  A1H8PY3QHMQQA0  0528881469         Dave M. Shaw "mack dave"   [9, 10]
# 3  A3QH8VQDE7HZCR  0972683275                   costaricachris  [15, 19]
# 4  A38FGQVJM18OWV  0972683275  George S. Mitchell "gsmitchell"   [8, 18]
#
#                                           reviewText  overall  \
# 0  I'm a professional OTR truck driver, and I bou...      1.0
# 1  Well, what can I say.  I've had this unit in m...      3.0
# 2  Not going to write a long review, even thought...      2.0
# 3  Quality was excellent. Instructions were clear...      5.0
# 4  I checked around Amazon as well as some other ...      1.0
#
#                     summary  unixReviewTime   reviewTime  helpfulness_score  \
# 0         Very Disappointed      1290643200  11 25, 2010           0.800000
# 1            1st impression      1283990400   09 9, 2010           0.955556
# 2   Great grafics, POOR GPS      1290556800  11 24, 2010           0.900000
# 3  Real value for the money      1286236800   10 5, 2010           0.789474
# 4     What a piece of junk!      1291161600   12 1, 2010           0.444444
#
#    user_deviation  review_delay  \
# 0        1.399189       6652800
# 1        0.624437             0
# 2        0.510375       6566400
# 3        0.442171       2678400
# 4        1.616074       7603200
#
#                                           stem_words  \
# 0  [im, profession, otr, truck, driver, bought, t...
# 1  [well, say, ive, unit, truck, four, day, prior...
# 2  [go, write, long, review, even, thought, unit,...
# 3  [qualiti, excel, instruct, clear, clear, tilt,...
# 4  [check, around, amazon, well, site, decid, nee...
#
#                                            lem_words stem_sim_words  \
# 0  [im, professional, otr, truck, driver, bought,...            [5]
# 1  [well, say, ive, unit, truck, four, day, prior...             []
# 2  [going, write, long, review, even, thought, un...             []
# 3  [quality, excellent, instruction, clear, clear...             []
# 4  [checked, around, amazon, well, site, decided,...             []
#
#                                        lem_sim_words  lem_set_length  \
# 0  [rand, route, weight, take, time, length, gps,...             160
# 1  [dock, feature, car, determine, home, rand, pa...             241
# 2  [screen, road, rand, route, truck, feature, tr...             159
# 3                                  [level, hardware]              31
# 4                                        [tv, mount]              52
#
#    lem_sim_length   lem_sim
# 0              13  0.081250
# 1              23  0.095436
# 2              16  0.100629
# 3               2  0.064516
# 4               2  0.038462

# %%
df_new['helpfulness_score'].corr(df_new['lem_sim_length'])
# Out:
# 0.17191611968338297

# %%
df_new['lem_sim'].isnull().values.ravel().sum()
# Out:
# 0

# %%
df_new.tail()
# Out:
#             reviewerID        asin                      reviewerName  \
# 107497   APRNS6DB68LLV  B00L26YDA4  Rob Slaven "slavenrm@gmail. com"
# 107498  A3A4ZAIBQWKOZS  B00L26YDA4                  Stephen M. Lerch
# 107499   A18R0PC372EGL  B00L3YHF6O                             Blues
# 107500  A3OOQH73VQ97VN  B00L3YHF6O                   Jem "Microsoft"
# 107501  A3A4ZAIBQWKOZS  B00L3YHF6O                  Stephen M. Lerch
#
#          helpful                                         reviewText  overall  \
# 107497   [5, 10]  As usual I received this item for free in exch...      5.0
# 107498  [10, 15]  Want to add wireless audio streaming to your h...      5.0
# 107499   [7, 11]  Wow...that's about all I have to say.  Having ...      5.0
# 107500   [5, 12]  Update 14 July 2014: they have a white paper a...      5.0
# 107501  [18, 23]  My short review:If you have the money to spend...      5.0
#
#                                                   summary  unixReviewTime  \
# 107497  Works brilliantly once you understand what it ...      1404172800
# 107498                                              Smart      1403827200
# 107499                     To use a technical term...Wow!      1404950400
# 107500                                 Purely Cons Review      1404777600
# 107501          Best sounding speaker at this price range      1404691200
#
#          reviewTime  helpfulness_score  user_deviation  review_delay  \
# 107497   07 1, 2014           0.500000        0.597583        432000
# 107498  06 27, 2014           0.666667        0.546834         86400
# 107499  07 10, 2014           0.636364        0.448464        259200
# 107500   07 8, 2014           0.416667        0.742179         86400
# 107501   07 7, 2014           0.782609        0.546834             0
#
#                                                stem_words  \
# 107497  [usual, receiv, item, free, exchang, review, a...
# 107498  [want, add, wireless, audio, stream, home, the...
# 107499  [wowthat, say, prior, experi, bt, speaker, rel...
# 107500  [updat, 14, juli, 2014, white, paper, creative...
# 107501  [short, reviewif, money, spend, speaker, dont,...
#
#                                                 lem_words stem_sim_words  \
# 107497  [usual, received, item, free, exchange, review...             []
# 107498  [want, add, wireless, audio, streaming, home, ...             []
# 107499  [wowthats, say, prior, experience, bt, speaker...             []
# 107500  [update, 14, july, 2014, white, paper, creativ...            [g]
# 107501  [short, reviewif, money, spend, speaker, dont,...         [n, w]
#
#                                             lem_sim_words  lem_set_length  \
# 107497               [receiver, speaker, get, wifi, need]              82
# 107498  [receiver, music, connection, wifi, sabrent, s...             129
# 107499         [fidelity, pair, performance, sound, roar]              99
# 107500    [sbx, control, audio, pair, power, panel, roar]             414
# 107501  [control, audio, pc, connection, pair, line, p...             473
#
#         lem_sim_length    lem_sim
# 107497               5  16.400000
# 107498               9  14.333333
# 107499               5  19.800000
# 107500               7  59.142857
# 107501              14  33.785714
