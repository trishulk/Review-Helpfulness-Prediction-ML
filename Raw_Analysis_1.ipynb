# %%
eval(1+1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-be3a1ba47c6d> in <module>()
# ----> 1 eval(1+1)
#
# TypeError: eval() arg 1 must be a string, bytes or code object

# %%
eval("1+1")
# Out:
# 2

# %%
d=eval("{1:4, 2:5}")

# %%
d
# Out:
# {1: 4, 2: 5}

# %%
type(d)
# Out:
# dict

# %%
import pandas as pd
import gzip

def parse(path):
  g = gzip.open(path, 'rb')
  for l in g:
    yield eval(l)

def getDF(path):
  i = 0
  df = {}
  for d in parse(path):
    df[i] = d
    i += 1
  return pd.DataFrame.from_dict(df, orient='index')

df = getDF('reviews_Electronics_5.json.gz')

# %%
df.head(10)
# Out:
#        reviewerID        asin                           reviewerName  \
# 0   AO94DHGC771SJ  0528881469                                amazdnu
# 1   AMO214LNFCEI4  0528881469                        Amazon Customer
# 2  A3N7T0DY83Y4IG  0528881469                          C. A. Freeman
# 3  A1H8PY3QHMQQA0  0528881469               Dave M. Shaw "mack dave"
# 4  A24EV6RXELQZ63  0528881469                            Wayne Smith
# 5  A2JXAZZI9PHK9Z  0594451647          Billy G. Noland "Bill Noland"
# 6  A2P5U7BDKKT7FW  0594451647                              Christian
# 7   AAZ084UMH8VZ2  0594451647  D. L. Brown "A Knower Of Good Things"
# 8   AEZ3CR6BKIROJ  0594451647                           Mark Dietter
# 9  A3BY5KCNQZXV5U  0594451647                                Matenai
#
#     helpful                                         reviewText  overall  \
# 0    [0, 0]  We got this GPS for my husband who is an (OTR)...      5.0
# ...

# %%
df[df['asin']=='0528881469']
# Out:
#        reviewerID        asin              reviewerName   helpful  \
# 0   AO94DHGC771SJ  0528881469                   amazdnu    [0, 0]
# 1   AMO214LNFCEI4  0528881469           Amazon Customer  [12, 15]
# 2  A3N7T0DY83Y4IG  0528881469             C. A. Freeman  [43, 45]
# 3  A1H8PY3QHMQQA0  0528881469  Dave M. Shaw "mack dave"   [9, 10]
# 4  A24EV6RXELQZ63  0528881469               Wayne Smith    [0, 0]
#
#                                           reviewText  overall  \
# 0  We got this GPS for my husband who is an (OTR)...      5.0
# 1  I'm a professional OTR truck driver, and I bou...      1.0
# 2  Well, what can I say.  I've had this unit in m...      3.0
# 3  Not going to write a long review, even thought...      2.0
# 4  I've had mine for a year and here's what we go...      1.0
#
#                                   summary  unixReviewTime   reviewTime
# 0                         Gotta have GPS!      1370131200   06 2, 2013
# ...

# %%
df[df['reviewerID']=='A23C0R77ZP9Z84']
# Out:
#              reviewerID        asin reviewerName   helpful  \
# 362      A23C0R77ZP9Z84  1400532655         Aeon   [1, 22]
# 115455   A23C0R77ZP9Z84  B0002LEMWE         Aeon    [2, 2]
# 220894   A23C0R77ZP9Z84  B000GYI76Y         Aeon    [0, 0]
# 268732   A23C0R77ZP9Z84  B000MXZ2XK         Aeon  [12, 14]
# 334867   A23C0R77ZP9Z84  B000VXQZ9Q         Aeon    [1, 1]
# 506420   A23C0R77ZP9Z84  B001P05NKG         Aeon    [1, 1]
# 628177   A23C0R77ZP9Z84  B002MU1ZRS         Aeon    [1, 1]
# 802940   A23C0R77ZP9Z84  B003NE5UWI         Aeon    [2, 3]
# 841595   A23C0R77ZP9Z84  B003WUX6PG         Aeon    [3, 4]
# 844762   A23C0R77ZP9Z84  B003XIJ3MW         Aeon    [0, 0]
# 882547   A23C0R77ZP9Z84  B0042A8CW2         Aeon    [0, 2]
# 986042   A23C0R77ZP9Z84  B004MMEI5A         Aeon    [8, 8]
# 1037816  A23C0R77ZP9Z84  B004W2JKWG         Aeon    [0, 0]
# 1092403  A23C0R77ZP9Z84  B0058AH2US         Aeon    [1, 2]
# 1192624  A23C0R77ZP9Z84  B005WFYGH6         Aeon  [26, 26]
#
# ...

# %%
def num_votes(arr) :
    return arr[1]

# %%
num_votes([0,4])
# Out:
# 4

# %%
df[df['helpful'].apply(num_votes) > 20].head(30)
# Out:
#          reviewerID        asin  \
# 2    A3N7T0DY83Y4IG  0528881469
# 211  A27K5RT7VDB7BU  0972683275
# 221   AGY0KH2D5G9WH  0972683275
# 263  A19N3S7CBSU6O7  1400501466
# 273  A2ILMCJBXWF5TS  1400501466
# 282  A35FTKYO9UQZWF  1400501520
# 284  A1GXOJYENYFP6W  1400501520
# 300  A3LDPF5FMB782Z  1400501776
# 307  A2FHM5FB0BXKGA  1400501776
# 316  A1MZVETF38AMZ6  1400501776
# 339  A3UCF82XIPJME2  1400532620
# 352  A2Q5OH3DGQGMXD  1400532620
# 354  A2EJPGQV89WOTD  1400532620
# 357  A1PPS91NLI7KEH  1400532620
# 362  A23C0R77ZP9Z84  1400532655
# 369   A4YAXWNMWYY0K  1400532655
# 389  A2VW6E1M1JP8JI  1400532655
# 399   A5JLAU2ARJ0BO  1400532655
# 406  A326VH8IUJ7JSV  1400532655
# 411   AQMUXDDCLJSSV  1400532655
# 454  A36CLMUHL8OBHJ  1400532655
# 457  A33Z318TMDAFDM  1400532655
# 481  A39K7R4Y1ZD5SZ  140053271X
# 505  A174P367YZ02ZE  140053271X
# 524  A2QDSC731OQC3P  140053271X
# 537  A1DCNMRBNSTN59  140053271X
# 549  A3M73KV733HBG3  1400532736
# 554  A1DQHS7MOVYYYA  1400599997
# ...

# %%
def unhelpful(arr):
    if arr[1]>0:
        if arr[0]/arr[1] <=0.3 :
            return 1
    return 0

# %%
unhelpful([5,10])
# Out:
# 0

# %%
len(df[(df['helpful'].apply(unhelpful) == 1) & (df['helpful'].apply(num_votes)>=5) ])
# Out:
# 17259

# %%
len(df[df['helpful'].apply(num_votes) >= 5])
# Out:
# 207965

# %%
len(df)
# Out:
# 1689188

# %%
# Out:
# 192403

# %%
df[df['helpful'].apply(num_votes) >= 5]['reviewerID'].nunique()
# Out:
# 87624

# %%
df['asin'].nunique()
# Out:
# 63001

# %%
print('Hello')
# Out:
# Hello

# %%
f = open('opinion-lexicon-English/positive-words.txt','r')

# %%
f.mode
# Out:
# 'r'

# %%
contents = f.read()

# %%
my_list = contents.split('\n')

# %%
my_list[:5]
# Out:
# ['a+', 'abound', 'abounds', 'abundance', 'abundant']

# %%
'aboudd' in my_list
# Out:
# False
