# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
fr_mae_sort = pd.read_csv('fr_mae_sort.csv')
fr_mae_sort
# Out:
#                          feature  correlation    mae-LR    mse-LR   rmse-LR  \
# 0                        overall     0.475150  0.146280  0.044177  0.210184
# 1                         pos_no     0.223190  0.169830  0.053830  0.232012
# 2                 user_deviation    -0.330468  0.160081  0.050528  0.224785
# 3                difficult_words     0.216660  0.170116  0.053960  0.232292
# 4                  review_length     0.196104  0.170669  0.054436  0.233316
# 5                 lem_sim_length     0.171916  0.170931  0.054989  0.234496
# 6                stem_sim_length     0.170400  0.170971  0.055008  0.234537
# 7          linsear_write_formula     0.014142  0.173186  0.056629  0.237968
# 8             coleman_liau_index     0.107465  0.172458  0.056024  0.236695
# 9                     smog_index     0.115414  0.172052  0.055855  0.236336
# 10                    user_delay    -0.094694  0.172626  0.056167  0.236995
# ...

# %%
fig, ax = plt.subplots(figsize=(19,10))
sns.set(context='talk', font_scale=0.9)
sns.barplot(x='feature',y='least_mae',data=fr_mae_sort[:10])
#fig.savefig('feature_mae_2.png')
# Out:
# C:\Users\Trishul\Anaconda3\lib\site-packages\seaborn\categorical.py:1460: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)
